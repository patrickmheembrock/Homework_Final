# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
# from api_keys import api_key

api_key = '3d661129cbc6f8a2cb5f69cd75f8cd55'

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
print("red")
# Out:
# red

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    print(f"Getting info for {lat_lng}.")
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# Getting info for (-83.94495470043796, -42.71746181251663).
# Getting info for (-55.985108919132635, 76.90872121653007).
# Getting info for (-39.05539927871345, 164.0407680757907).
# Getting info for (-39.74003053771405, -151.40432034238933).
# Getting info for (-62.878709007791116, -7.112762619014006).
# Getting info for (-48.62444463401837, -148.88335535110684).
# Getting info for (-1.013932695596793, 136.6310345554577).
# Getting info for (66.009086038263, -52.244801191350035).
# Getting info for (-49.38742298196106, 56.82826105932324).
# Getting info for (-16.586960825848763, 79.13640920975575).
# Getting info for (40.021433638768315, -27.761591471538196).
# Getting info for (-60.79520525038295, 83.0301780620602).
# Getting info for (67.13292850256903, 161.15617952778342).
# Getting info for (47.79229751092822, 31.77976573959768).
# Getting info for (-85.34287344006843, 153.85064780370504).
# Getting info for (58.754543765494816, 56.75715815704302).
# Getting info for (-47.55097309866682, -77.53852972197622).
# Getting info for (-61.43550097675797, 72.07911590409145).
# Getting info for (84.29948923284795, 34.507241015093115).
# Getting info for (-51.13372847019496, 60.25985512899055).
# Getting info for (-78.388115352919, -130.94731639003282).
# Getting info for (44.79615218638162, -25.18878671590022).
# Getting info for (-64.49275205952722, -1.9139316152326273).
# Getting info for (-24.158449372766924, -101.75054764648576).
# Getting info for (17.035759767883278, -124.97896848618291).
# Getting info for (-48.621430184950604, -142.47669851595782).
# Getting info for (22.733452300491095, -71.24549469870144).
# Getting info for (-60.7656927960132, -144.84642046336373).
# Getting info for (84.77554607420348, 166.81537272819992).
# Getting info for (25.15368108921396, -80.40828692225543).
# Getting info for (36.24873011116054, 94.62495173618106).
# Getting info for (81.79029634688757, -159.71704756990334).
# Getting info for (87.88472010907765, 94.07689482598079).
# Getting info for (16.65392541921058, -2.271584770703157).
# Getting info for (-17.04911099632362, -179.17632857038734).
# Getting info for (-66.97551806469399, -158.18590850764565).
# Getting info for (-24.745646759678507, -86.58819815643169).
# Getting info for (-84.13186518827271, -92.31405180516705).
# Getting info for (-88.06863565133756, -90.24657044413455).
# Getting info for (83.4180789134443, -119.82364751402932).
# Getting info for (7.855063461918704, 60.365802441861604).
# Getting info for (5.7885488760531985, 62.64705063214615).
# Getting info for (38.799574883427255, 52.615649790627714).
# Getting info for (-40.142277398655935, -175.83595399889649).
# Getting info for (72.44136460628087, -81.9323386821432).
# Getting info for (60.21206313166624, 36.703292434649626).
# Getting info for (55.323882974231225, -38.315903754614624).
# Getting info for (-35.73146980390926, -24.265398642480875).
# Getting info for (-51.58006578069313, 21.159059074449033).
# Getting info for (12.945114391078377, -155.30799142833334).
# Getting info for (-42.7739492264746, 152.25005775577114).
# Getting info for (-80.02132650960525, 97.92828504598214).
# Getting info for (-36.15796323842714, -60.49320246646185).
# Getting info for (48.924880364138744, -167.03865571402093).
# Getting info for (15.798413405815126, 167.217316813151).
# Getting info for (-37.23004472213457, -26.249524475126748).
# Getting info for (86.45654535022246, -90.7069753595691).
# Getting info for (-86.46822197975378, 25.145151191344098).
# Getting info for (-1.7144485244778167, -147.7467708016972).
# Getting info for (-60.49519857318619, 135.69961963412464).
# Getting info for (30.3021212015513, 106.5623284062055).
# Getting info for (-4.800077063159506, -5.756281544545345).
# Getting info for (-6.127622164515799, -62.23425115073576).
# Getting info for (78.0761278218888, -107.3088916861149).
# Getting info for (-13.918179361118234, -87.91114713967634).
# Getting info for (88.35388412768881, 138.76195791995696).
# Getting info for (50.82601251770163, -31.197319337671246).
# Getting info for (-72.59421366250872, 93.3823610292742).
# Getting info for (31.99596999100264, 135.5753981896956).
# Getting info for (18.262125989868466, 96.95773854371646).
# Getting info for (-52.18556431288383, -162.23656093972124).
# Getting info for (78.75349592314146, 153.71927160840426).
# Getting info for (-44.54251606246532, -63.023798124632194).
# Getting info for (-51.65851387463064, -73.85260895638493).
# Getting info for (-30.66341306365654, -130.7125280142845).
# Getting info for (12.606739077467921, 103.25839259368581).
# Getting info for (-63.41430520685022, -150.91606737963997).
# Getting info for (61.439829938156265, -122.33471660842503).
# Getting info for (79.62914004626887, 170.02617352437113).
# Getting info for (-70.8720095540403, -145.5164863411738).
# Getting info for (-83.93187201253113, -64.98851935788822).
# Getting info for (50.84822604602684, 71.14718057900419).
# Getting info for (6.413436986200992, -17.587243638244416).
# Getting info for (-47.14494333139437, 131.08010083003876).
# Getting info for (-66.74409737344945, 164.36764982437677).
# Getting info for (-32.79064184702509, 95.53049832648242).
# Getting info for (-44.590131491319525, 40.44717809311132).
# Getting info for (1.1402110466365798, -5.2325618602610575).
# Getting info for (-40.3556185923089, -165.85862857913335).
# Getting info for (-81.4052510852998, -40.95151586341211).
# Getting info for (21.930733692959762, 61.072166690685236).
# Getting info for (56.16397262101839, -135.83431913968104).
# Getting info for (-38.525661699864386, 82.31518606977784).
# Getting info for (-54.20934235051839, 15.829197531597032).
# Getting info for (30.274046133206966, 162.68457587655786).
# Getting info for (35.53299297779985, -101.37241094955775).
# Getting info for (-33.75489101171623, 60.744129773478505).
# Getting info for (20.777338958518797, 123.2151904050977).
# Getting info for (-71.83870817568373, -56.37349718253631).
# Getting info for (4.4145324096742655, -71.90715184918795).
# Getting info for (-85.75399605214228, -75.31772033768064).
# Getting info for (15.198899528458924, -136.6413688885707).
# Getting info for (-2.191062821074226, -2.9711173834614613).
# Getting info for (-9.500156335171354, 134.10010210981642).
# Getting info for (-29.734923935724098, -14.674852498683663).
# Getting info for (3.926142474471277, -31.412343803531826).
# Getting info for (76.59523409531067, -23.57090562071471).
# Getting info for (-1.3078935965888405, 26.319768788385915).
# Getting info for (77.826478103764, 46.89438687227181).
# Getting info for (60.208150806968774, -118.06416010132568).
# Getting info for (-61.33867646712326, 45.800327442026344).
# Getting info for (-35.48199221775117, -137.92372399183188).
# Getting info for (-31.635100897071254, -99.91013509663937).
# Getting info for (68.49730911029943, -145.2859090859734).
# Getting info for (81.90043947865047, -142.94386908449044).
# Getting info for (52.608254534987566, -141.73279854683994).
# Getting info for (-80.68371762904485, -11.521281460256745).
# Getting info for (32.43085334011907, -57.2050509973638).
# Getting info for (4.940109117683463, -86.27086171745813).
# Getting info for (-10.845029603968158, 6.413891007584766).
# Getting info for (53.84187852602301, 53.28642635277629).
# Getting info for (-43.024093736948664, 50.467891326706734).
# Getting info for (20.1231536813805, 24.113807551882587).
# Getting info for (70.51210421194341, -172.01876653345258).
# Getting info for (-11.052898014378599, 90.45820525414615).
# Getting info for (67.42481691337511, -150.88255601182456).
# Getting info for (-38.36952382271147, -33.4390644250646).
# Getting info for (-39.38887350987612, -22.514663196263683).
# Getting info for (2.332960840201295, -149.4624456488086).
# Getting info for (-61.17751465647376, -55.18492869677566).
# Getting info for (88.58839224626072, 130.83479760852669).
# Getting info for (-9.372650629999029, 6.651467084638938).
# Getting info for (71.01916585860405, 15.864921597244575).
# Getting info for (83.10422618748518, 45.86361511456937).
# Getting info for (35.02527746364474, -86.41154208026418).
# Getting info for (-13.561523233534587, 26.69171507860881).
# Getting info for (-68.15639955028348, -64.88285407452878).
# Getting info for (-71.40815600578745, 79.91045449062636).
# Getting info for (12.709086596891382, -140.97133960789785).
# Getting info for (23.050837965994077, 110.74550129402962).
# Getting info for (49.40163954820366, -104.75069675999704).
# Getting info for (-78.63715332200505, -85.79751346114017).
# Getting info for (58.57746622010728, 115.24173157828653).
# Getting info for (80.09442562677589, -177.40050845848828).
# Getting info for (-65.268247462402, 116.45869189528344).
# Getting info for (-1.0564870339680965, 70.73478990227255).
# Getting info for (-68.41174745880272, 163.39005672808298).
# Getting info for (44.231829444485214, -142.46097632897545).
# Getting info for (-30.384926387431634, 87.99272055318454).
# Getting info for (-8.085319634026888, 162.45507080753816).
# Getting info for (81.70280875905993, -5.553686384369598).
# Getting info for (47.24950790452979, 121.69581584303023).
# Getting info for (-79.80135972220779, -101.65633605568974).
# Getting info for (46.538227476417575, 92.74828294557864).
# Getting info for (-75.96550926929397, -144.91753251009644).
# Getting info for (86.69138503402593, -137.97402948278628).
# Getting info for (-54.484438752687325, 152.27734789528517).
# Getting info for (83.99529350652224, 169.35533107230907).
# Getting info for (86.3687728539314, -81.69947993255587).
# Getting info for (46.966462302922, -116.02835069393274).
# Getting info for (42.26302205095223, -125.05565334256397).
# Getting info for (25.683541851553997, 10.606655643010384).
# Getting info for (65.80848020244363, 80.68921863685739).
# Getting info for (20.734818854040242, 26.54456285517702).
# Getting info for (-87.99845445531126, 27.605611995835318).
# Getting info for (25.7819066150102, -110.86737713197058).
# Getting info for (75.2169019814572, -82.33404556505619).
# Getting info for (-68.14305535815495, 139.1786484232709).
# Getting info for (-55.29275494131108, 0.5578654671293464).
# Getting info for (81.6943727433443, 23.351600185903635).
# Getting info for (31.118551425068404, -134.5793635868552).
# Getting info for (4.416956000332817, -159.6088513373472).
# Getting info for (-5.488144151265459, 169.15030835653482).
# Getting info for (-6.618777276518813, -121.669683872673).
# Getting info for (60.80036444848389, 54.85719695357835).
# Getting info for (29.22589757973597, 2.3805624531512137).
# Getting info for (-76.55206603923183, 133.75013376294396).
# Getting info for (-50.47361002605038, -60.005998254106274).
# Getting info for (-0.4137963045959765, 59.26234224960089).
# Getting info for (30.47717116809683, 163.90018611640357).
# Getting info for (60.89351928076974, -35.16424571920163).
# Getting info for (3.8079715590193928, -94.572391611011).
# Getting info for (32.81603677746129, -142.4426682029926).
# Getting info for (53.70080772850531, -51.90156799907231).
# Getting info for (-65.90392956745042, 118.03967924446414).
# Getting info for (35.89170838036004, 9.728052229808668).
# Getting info for (-44.7383309640605, -174.46965950054104).
# Getting info for (-8.646320700702248, -164.74693147579276).
# Getting info for (47.77022785387726, -28.635255960270115).
# Getting info for (-22.156577237387197, -124.52919583011615).
# Getting info for (55.87769576372634, -96.87179420220893).
# Getting info for (-72.25175934198448, -177.8969443723492).
# Getting info for (-72.09955862986565, 137.8094533679357).
# Getting info for (-85.42694159920205, -20.495807240241675).
# Getting info for (-37.01367339780261, -44.2966224960532).
# Getting info for (38.70636962893943, -16.20282870572072).
# Getting info for (43.26410209736136, 38.89654245942461).
# Getting info for (29.33472542932202, -25.68474357642998).
# Getting info for (23.496360427574103, 119.08983217424822).
# Getting info for (35.01940216062164, -81.94719611833102).
# Getting info for (-85.59296234727312, -14.802742653795548).
# Getting info for (-67.83308477067102, 119.40950091561126).
# Getting info for (-35.55203148735442, 77.99442151635236).
# Getting info for (27.899715499786552, 37.48175764539931).
# Getting info for (76.33122503416621, -179.03717552288563).
# Getting info for (66.74977773767071, -175.364245781599).
# Getting info for (-27.46482503600228, -155.1507275939038).
# Getting info for (-76.87800285073098, -109.90350147831424).
# Getting info for (-21.14347595812781, 137.15857024466277).
# Getting info for (-28.072294157796357, 1.1241391472155158).
# Getting info for (-52.284337471959496, -26.473518022658908).
# Getting info for (46.71581052760294, 67.36708191097708).
# Getting info for (16.872397237780092, 116.71891455892319).
# Getting info for (25.493909295422682, 82.91997750670708).
# Getting info for (-55.98186734489037, -160.81737432871685).
# Getting info for (59.07285645824115, 83.71713737687702).
# Getting info for (-15.543174604157556, 169.8027550187329).
# Getting info for (22.6367625994845, 151.42821542300908).
# Getting info for (-85.17734198157628, 157.5336550667356).
# Getting info for (16.474095556706374, 148.738463101614).
# Getting info for (52.537278507502805, 59.8284077412149).
# Getting info for (16.769597064738576, 139.90584362022605).
# Getting info for (-80.35309763388187, 160.14945443230312).
# Getting info for (45.17659706798116, -146.415577606084).
# Getting info for (-22.500908909989633, -10.352751280762106).
# Getting info for (-45.55471103864184, -126.71001650507691).
# Getting info for (28.23251464034051, 28.14260143258474).
# Getting info for (66.44861886717712, 148.3108593356484).
# Getting info for (-21.18932916028288, -77.28277081954641).
# Getting info for (-61.18210703977396, 166.02469910059517).
# Getting info for (-88.49296625100838, 114.46160451699052).
# Getting info for (59.941184306617544, 92.4148514639079).
# Getting info for (64.71529167771533, 81.17589359315502).
# Getting info for (48.61783453988724, -82.79427530017689).
# Getting info for (-78.6190356240237, -141.32645728445922).
# Getting info for (61.514986904424376, -74.31939385662238).
# Getting info for (57.63375494670021, 101.69913853781952).
# Getting info for (23.639438180942705, 64.46667617477397).
# Getting info for (27.188187548158695, 125.3500611980379).
# Getting info for (-21.46351048634226, 174.57586042988783).
# Getting info for (-17.31674703000033, 156.7543459359244).
# Getting info for (6.647856836552592, 21.524970340579927).
# Getting info for (56.79996221614698, 128.22986299200755).
# Getting info for (14.777869318128708, 9.584325998176098).
# Getting info for (-82.29643125293352, -1.5850423977459798).
# Getting info for (-56.87604809552471, -1.6878505539183948).
# Getting info for (8.858833750003868, 54.264462952755906).
# Getting info for (-26.416563617007, -36.654212931820666).
# Getting info for (-23.130872972678162, 43.86183217992959).
# Getting info for (-43.166092773040425, 53.762965648815765).
# Getting info for (25.529512852241297, -167.34615653600136).
# Getting info for (-42.742422754531255, -53.479026416651024).
# Getting info for (19.430059888958382, -81.27712817709335).
# Getting info for (-28.6681819081505, -81.89851504557546).
# Getting info for (-25.254538028074975, -9.595273578126097).
# Getting info for (-5.070586603003193, -89.25177287192346).
# Getting info for (45.56146330081802, -142.0010964278219).
# Getting info for (0.28854386280417543, 29.109305827044892).
# Getting info for (49.739254663167486, -52.442776029302806).
# Getting info for (32.42354698301216, 78.85908479949506).
# Getting info for (27.005780200624557, 141.34112706672886).
# Getting info for (-59.3589747373393, 83.36671415303971).
# Getting info for (-53.86928843275741, -127.56716654054698).
# Getting info for (-27.33883607430335, -41.47216995911745).
# Getting info for (58.74758622302852, 50.089160232556935).
# Getting info for (-45.66486762767278, 47.816229242865006).
# Getting info for (-70.52486490653531, -63.10725889645032).
# Getting info for (-89.07149011472508, -25.761394740239353).
# Getting info for (-32.231764630801116, 135.09477439847166).
# Getting info for (41.48057021400345, 53.32477876667511).
# Getting info for (18.42105383131897, -10.052935106605304).
# Getting info for (-36.41471446269581, 135.95844353422387).
# Getting info for (24.330637191901687, 100.81345538127272).
# Getting info for (-44.448235858406925, -38.1954273103789).
# Getting info for (81.71122599238717, 168.20658966793928).
# Getting info for (-63.8493859938787, -113.28912782554784).
# Getting info for (-17.88754052721778, 5.948536133124605).
# Getting info for (0.5975870745690912, 133.66500778318613).
# Getting info for (75.85802878798717, -55.192588561328094).
# Getting info for (8.01082494447509, 70.92476765879337).
# Getting info for (-19.906956570860388, 68.44724503173623).
# Getting info for (11.660066701745393, -56.96718280200136).
# Getting info for (-65.61314952039109, -28.86109094102366).
# Getting info for (18.91598282407014, 91.12159431478796).
# Getting info for (7.066478260033847, 132.57973118115478).
# Getting info for (72.62925876306304, -50.21918834681202).
# Getting info for (-44.75237576826292, -168.2602142854353).
# Getting info for (38.52357051963057, 72.92362139675814).
# Getting info for (54.91202750266601, 120.06337938111733).
# Getting info for (79.59850833160675, 9.860215653401951).
# Getting info for (-85.5571252635543, 135.10521127846806).
# Getting info for (-88.45627306892253, -32.1830674501781).
# Getting info for (51.69167549348239, -161.1419399538724).
# Getting info for (-4.225844589707492, 165.40967108544623).
# Getting info for (-17.2730563134416, 33.69589916266929).
# Getting info for (-87.65596578282316, 167.05581260588065).
# Getting info for (19.218341049804465, -16.662959191391792).
# Getting info for (-17.48870918177478, 91.23915365374864).
# Getting info for (-9.819132280303833, 168.941452141298).
# Getting info for (41.16124412001625, -11.120546328847155).
# Getting info for (-53.67013280026149, -150.2606932193733).
# Getting info for (67.47071920615437, -21.62871505648488).
# Getting info for (80.38887764607318, -167.14241583596043).
# Getting info for (-15.494400261688497, -125.83018426138247).
# Getting info for (28.289535513458546, 25.020767502960183).
# Getting info for (70.92578074423679, -73.06635488823389).
# Getting info for (-6.908565612454382, 57.86684322036825).
# Getting info for (3.5258220258361064, 45.35274577302849).
# Getting info for (47.44960095420075, 13.545231124020916).
# Getting info for (-56.462845129847096, 59.529585447290145).
# Getting info for (61.33037076977331, 147.86497675647036).
# Getting info for (44.39960693582924, -55.81532274485427).
# Getting info for (23.811411220031147, -37.84827173549726).
# Getting info for (47.30491341493112, -117.78176421945298).
# Getting info for (67.98317313573631, -76.201220970198).
# Getting info for (16.574854941499197, 0.1870179559379892).
# Getting info for (-3.9390877433287415, -57.327813419374635).
# Getting info for (-82.11952727566803, -151.3139103994284).
# Getting info for (80.40633059404354, -32.215980535784894).
# Getting info for (34.51993975433615, 103.18027094793581).
# Getting info for (-27.54247546938366, -110.57396364884161).
# Getting info for (42.703092051636446, 165.16974028186723).
# Getting info for (20.286904703068004, 27.898013028061968).
# Getting info for (-62.03911279783665, -84.23747511843636).
# Getting info for (-31.339214522887303, 149.12249898689714).
# Getting info for (-64.64552800084213, -63.74393547954671).
# Getting info for (20.30159081275255, 1.258038660593627).
# Getting info for (31.146605229926763, 138.3101183810664).
# Getting info for (-3.325339088895902, 108.62566686946388).
# Getting info for (-82.78974096713169, -153.61912897021355).
# Getting info for (-57.19321910249849, 112.79130481362631).
# Getting info for (16.03735536917121, -152.1984914430524).
# Getting info for (-3.478317908971036, 79.93962270753303).
# Getting info for (39.10200248780782, 69.4317311946163).
# Getting info for (-65.13915154777189, -124.7384664699541).
# Getting info for (-45.35812658102595, 12.022895382613115).
# Getting info for (-59.438149771531144, 166.3545452810211).
# Getting info for (-25.254343201053047, 153.44305694727166).
# Getting info for (-10.293786975127404, -10.683149172968513).
# Getting info for (-61.2641922787191, -1.6431206457219787).
# Getting info for (-79.40459090534692, -39.01573939041617).
# Getting info for (-65.19880469019009, -8.498270821111703).
# Getting info for (-36.946555191605526, -105.75207722219024).
# Getting info for (-75.94804094068785, 22.17480252174775).
# Getting info for (26.8487923890207, 123.85967162034723).
# Getting info for (-65.18642344645038, -3.4863596883007233).
# Getting info for (-22.770260919967328, 45.158320671681196).
# Getting info for (18.22474091617559, 179.36594742309484).
# Getting info for (12.16216561178129, 108.8117705862943).
# Getting info for (89.05408886320015, -2.5043084959577584).
# Getting info for (-63.33226100903008, -154.52055122103215).
# Getting info for (83.22831066441762, -130.91284088831378).
# Getting info for (26.312749262564452, 100.71130721889773).
# Getting info for (86.87008050386007, 90.01804981405257).
# Getting info for (-4.012906300077304, 129.93190008442224).
# Getting info for (-37.79915523466753, -125.25129026245567).
# Getting info for (13.16236174443344, -61.331477295360074).
# Getting info for (15.235321992479228, -81.699944354114).
# Getting info for (11.622770847462377, -92.12947559879562).
# Getting info for (12.044215981685468, -155.36533437652136).
# Getting info for (-77.88609357709545, 8.8064431985932).
# Getting info for (-38.611168378593696, -16.942647585992745).
# Getting info for (71.95557023526254, 31.215337485810664).
# Getting info for (35.43752152948991, 50.05078759312542).
# Getting info for (-43.497628803171516, 63.60337689698528).
# Getting info for (49.112351258117826, 12.024495076162708).
# Getting info for (-45.472275315760086, 145.39544616887417).
# Getting info for (25.408622980015267, 49.174363583290045).
# Getting info for (-62.866151362607226, -52.77224308225017).
# Getting info for (-16.754556042704408, 172.13512373028107).
# Getting info for (17.400095756272336, -84.14041324897386).
# Getting info for (-88.2685804184943, 27.87731824371639).
# Getting info for (-29.497963750210552, 148.70722144041662).
# Getting info for (-17.673916800416492, 130.22102274365437).
# Getting info for (11.041606181433394, 107.61406834399173).
# Getting info for (-67.34552308992266, -12.024981404783261).
# Getting info for (-7.856806679126805, -72.14447387427131).
# Getting info for (22.311558620158166, 170.5242978751279).
# Getting info for (-84.54760661447791, -123.34005027049079).
# Getting info for (-34.7229919509371, -146.54583185603923).
# Getting info for (-35.33121092989799, -157.2940024270967).
# Getting info for (-88.03508746090603, 145.60983319788113).
# Getting info for (58.50595789467013, 10.458384895856227).
# Getting info for (-15.62984003484128, 78.79358762556404).
# Getting info for (76.4784846203979, 144.6554262582659).
# Getting info for (-49.70447484137672, 136.21214750488275).
# Getting info for (86.51751115979465, -83.36514315994388).
# Getting info for (-56.46278021017176, -24.335494801104886).
# Getting info for (-78.60799207392384, -140.82178062714087).
# Getting info for (-30.879026888637753, 37.78041925661992).
# Getting info for (-64.83413937485014, -150.7827229047833).
# Getting info for (64.29503469668794, -99.7901743552067).
# Getting info for (-21.071203853909907, -156.52966648567673).
# Getting info for (82.40595270651093, -171.20211050839487).
# Getting info for (78.80198640149942, -1.6361667044263584).
# Getting info for (29.659292516007397, 22.42698803259418).
# Getting info for (-87.45153342733796, 85.87083053733875).
# Getting info for (-27.43686614910304, 66.04726803943356).
# Getting info for (26.986350638170634, 72.66488028034715).
# Getting info for (30.82137541437139, 153.220177505999).
# Getting info for (55.71054998501583, 48.60357505047159).
# Getting info for (70.4473006938405, -147.27451667376198).
# Getting info for (5.106257687664311, -84.30298568222665).
# Getting info for (57.243062598567604, -131.00040100828164).
# Getting info for (77.24375408795552, -60.20725897053052).
# Getting info for (54.483100308191126, -125.54831085307879).
# Getting info for (-62.13028585186363, 131.584294178888).
# Getting info for (75.77354813230824, 151.52508949671477).
# Getting info for (7.239867795649886, 42.38661137705).
# Getting info for (82.32618692188643, -110.25755227938131).
# Getting info for (-80.96391292320898, 67.76565703793747).
# Getting info for (66.28398019892052, 145.8819353109102).
# Getting info for (82.46122709338974, 25.448287639668024).
# Getting info for (-17.911594086513816, -36.16021044050143).
# Getting info for (2.925036495240988, 12.85590221808252).
# Getting info for (70.7811668728367, -25.515230547658604).
# Getting info for (85.39539385811824, -79.83871073910231).
# Getting info for (33.33315846430331, 3.4812521978976747).
# Getting info for (2.238186288949038, 18.007883405671322).
# Getting info for (1.5301226086748585, -64.56075327064522).
# Getting info for (3.159730773212331, -70.28806503292776).
# Getting info for (-6.996328897684691, 2.7284130666460555).
# Getting info for (-33.08573941355764, -21.31282648117684).
# Getting info for (-57.28183906071069, 34.98576674116521).
# Getting info for (65.41290192681558, -105.1693855339818).
# Getting info for (-59.033264765345635, 80.25474239186326).
# Getting info for (-62.75556422852815, 73.72398029296687).
# Getting info for (-76.77403989400652, -172.64969175043998).
# Getting info for (65.57465924175261, 92.30297917254421).
# Getting info for (41.25244042358594, -173.89609425026086).
# Getting info for (-84.41665893952222, 10.27068959514125).
# Getting info for (-75.59741609774919, 89.419496812413).
# Getting info for (-36.801810114500825, -115.9352251684917).
# Getting info for (80.88074815404329, 124.71824650171584).
# Getting info for (-71.1442338409882, 149.54202718336137).
# Getting info for (-44.6586204697167, 13.586439327026142).
# Getting info for (-78.91784717135074, -168.6261670487859).
# Getting info for (43.46141891229064, 133.8395565018979).
# Getting info for (68.01875778721768, -127.52905603877133).
# Getting info for (78.4225032340178, 118.81186959482318).
# Getting info for (-65.335454953039, -107.40526740501033).
# Getting info for (-54.82779709273765, 10.363969546501494).
# Getting info for (50.96879091820199, -143.19254247540596).
# Getting info for (65.7300758620284, -120.2011966339168).
# Getting info for (-79.70500577828503, 175.6258989534433).
# Getting info for (-4.539257112927373, -108.04439733493201).
# Getting info for (-66.96898270787543, -114.37796552484095).
# Getting info for (17.714701790349096, 120.59276448755128).
# Getting info for (-55.928597065033046, 115.21969296693698).
# Getting info for (48.11300148033612, -40.893511763498424).
# Getting info for (49.49729786685222, 146.6261625551735).
# Getting info for (65.34646385895678, 179.16187019734593).
# Getting info for (-31.93877949677107, 58.14735348163521).
# Getting info for (-72.51422552581666, -86.63490487269287).
# Getting info for (-40.29624945545647, -56.19520906684659).
# Getting info for (-35.53783842639417, -62.13690252457526).
# Getting info for (58.94602381720452, -172.3966382172632).
# Getting info for (-81.50566235296374, -14.860789871194868).
# Getting info for (-59.408108913850526, -12.147953600467275).
# Getting info for (59.12399197219139, 76.50769470729324).
# Getting info for (-89.67941535469814, -147.18992708755917).
# Getting info for (23.73128642369919, -171.17269218190089).
# Getting info for (75.57754371855972, -139.2176599150165).
# Getting info for (31.29843836598721, -79.66650175804408).
# Getting info for (40.57470002604518, -118.3413145983306).
# Getting info for (-9.318895495502119, 41.02273782804866).
# Getting info for (-80.10725373364251, 160.14441684308656).
# Getting info for (-76.65650350169473, -95.31597537838715).
# Getting info for (0.7037678709575061, -121.69692517120319).
# Getting info for (23.200613635557417, -99.64471058974136).
# Getting info for (-20.139784933961366, 2.3885735914476243).
# Getting info for (-47.35843638436642, 97.66983229041023).
# Getting info for (-28.283595164182294, 69.10989807827644).
# Getting info for (-34.59816719655246, -128.93087798224724).
# Getting info for (-73.27368457184818, -105.67340908333524).
# Getting info for (-16.459218838541062, -26.74886396242414).
# Getting info for (-28.335909247018975, -0.8319325717335744).
# Getting info for (-58.64901014692673, -162.1322444399111).
# Getting info for (-75.82450159235177, 74.49770995061553).
# Getting info for (71.82341744686258, -74.39340741795313).
# Getting info for (6.889366715154907, -111.54571440743706).
# Getting info for (53.42133459671305, -54.2186565246743).
# Getting info for (-48.021665975349656, 31.284561707176522).
# Getting info for (-9.526020945365175, -45.54637138783997).
# Getting info for (-87.33275553558087, -144.85343257391207).
# Getting info for (71.46287334778927, 88.3779628947837).
# Getting info for (-61.63406993624186, 168.97096034244368).
# Getting info for (-86.15747791670637, -103.18718398183923).
# Getting info for (54.46543860509544, -24.103964548253344).
# Getting info for (10.818375095066529, 11.470820382732796).
# Getting info for (81.59820848260696, -7.918515726256572).
# Getting info for (77.29280953751768, 39.44967761175755).
# Getting info for (45.016035863058335, 11.126899239120661).
# Getting info for (69.66264540406354, 21.97998630994681).
# Getting info for (6.788219320354628, 22.388066451488186).
# Getting info for (-48.03078039585367, 121.688481108122).
# Getting info for (34.12908594673583, -117.63969393050951).
# Getting info for (2.7990927942672954, -144.3372293357196).
# Getting info for (-4.255135252209712, 172.5947011468573).
# Getting info for (-78.16040131529954, -115.04220873902305).
# Getting info for (55.665244383673894, -139.04324567978676).
# Getting info for (-52.09440645637049, 52.389142451757834).
# Getting info for (-41.139103579269545, 11.590233486306431).
# Getting info for (-47.14298999073365, 106.32437826345745).
# Getting info for (12.327030235972288, 139.23580968337137).
# Getting info for (-58.44190584434628, 1.984893277294674).
# Getting info for (-70.57450957361559, 24.193438726024567).
# Getting info for (41.20515601236434, 111.83927815305043).
# Getting info for (13.415749067003276, 56.78467730636581).
# Getting info for (70.63942826309574, -115.91815222586253).
# Getting info for (-10.708899520146758, -39.14891861421577).
# Getting info for (-48.835546758921744, 74.41311271187041).
# Getting info for (-37.81900672343315, -91.487092003316).
# Getting info for (86.07735544312669, 25.386316884077814).
# Getting info for (57.598089442386424, -15.987692999418357).
# Getting info for (72.56003352740254, -76.55895362213573).
# Getting info for (-3.77699689486181, -169.17674669611466).
# Getting info for (-31.663015560538412, -30.076025680190753).
# Getting info for (28.753003425416225, 65.78644092363643).
# Getting info for (13.139733675673739, -31.895331980720442).
# Getting info for (51.49687099194793, 155.29159938832856).
# Getting info for (42.52410145266998, -55.175734745507185).
# Getting info for (-73.53743383637907, 148.54415670886038).
# Getting info for (17.634770846042187, 64.03884534728044).
# Getting info for (-24.524882210912637, -112.9674153847292).
# Getting info for (-38.72312631498356, -141.89783129959935).
# Getting info for (-37.54561723696566, 25.99090322228102).
# Getting info for (-54.80384353164806, -134.17074328624798).
# Getting info for (40.444235745645244, -125.08371755139581).
# Getting info for (-36.03816795901278, 106.68627052673952).
# Getting info for (-48.03560767366379, -86.8056010013316).
# Getting info for (-4.187094388241235, -116.35714022698568).
# Getting info for (-59.706831839177795, -46.16368510996651).
# Getting info for (-21.14172123904754, 150.80028640982835).
# Getting info for (-68.54751041448162, 127.51928217682848).
# Getting info for (-27.019972078048326, 107.55521494754106).
# Getting info for (-16.134895474935306, -111.96591143092519).
# Getting info for (66.3300783441328, 83.45781147092873).
# Getting info for (-30.942388052711493, -52.25995136798163).
# Getting info for (39.144109633514944, -145.43865962591744).
# Getting info for (-47.56126124727836, 141.78640141792005).
# Getting info for (54.665661649406786, 95.03088784091653).
# Getting info for (-47.90743778426206, 83.25938043562678).
# Getting info for (33.901631252472484, 4.075724639402694).
# Getting info for (57.07007675070224, -107.44959825459102).
# Getting info for (73.11121503238965, -179.4517675333562).
# Getting info for (-30.491665334307157, 178.58296078430033).
# Getting info for (34.90915368464927, 96.48480332033557).
# Getting info for (24.54233595588775, 97.78454403591928).
# Getting info for (10.304831312201557, -120.42553401653348).
# Getting info for (33.51984936259386, -74.89417520801389).
# Getting info for (79.10506688148519, 111.86689506256607).
# Getting info for (-74.26677114339016, 173.39835267355545).
# Getting info for (-19.62187392869407, -2.1833780770688804).
# Getting info for (31.74237750956057, 14.12221600820223).
# Getting info for (-68.87529802052026, -2.300982413764018).
# Getting info for (-17.255642722997635, 22.77882308956646).
# Getting info for (59.38984496965804, 110.86859527942471).
# Getting info for (-86.86703390164617, 102.99456013198261).
# Getting info for (-67.10671917596713, -125.19826359431755).
# Getting info for (-35.02936235008804, 82.62963777047327).
# Getting info for (-57.034203160823665, 122.62407979238299).
# Getting info for (-69.1063189203795, -112.48640548880016).
# Getting info for (63.75442193094949, -54.71196353089191).
# Getting info for (-62.63180405069676, 142.1291723958692).
# Getting info for (20.483560963838457, 15.567300170861301).
# Getting info for (69.47940987357777, -70.90329497940398).
# Getting info for (-70.19424362043182, 59.45570252113157).
# Getting info for (16.699631904783672, -114.04288917728795).
# Getting info for (29.361641023180724, -113.52287333883655).
# Getting info for (-88.90242576494086, -140.0018758366997).
# Getting info for (-22.327880257388003, -33.41874321166736).
# Getting info for (-49.690737268346545, 179.17152602130813).
# Getting info for (-74.68592354196372, 120.83555828971208).
# Getting info for (-13.882007844378961, 160.0014307023814).
# Getting info for (79.83037939095948, 21.52843611303942).
# Getting info for (-48.33734549759767, -163.20799085798143).
# Getting info for (60.45353499241952, 24.38365909282433).
# Getting info for (-47.46896435435569, 75.39060044812979).
# Getting info for (-79.73557113985373, -121.33854527474742).
# Getting info for (41.975660380451785, -32.369456656363184).
# Getting info for (46.50862035039444, -21.833724000041315).
# Getting info for (48.082911068584764, 21.659492801901763).
# Getting info for (56.473616333366465, -44.37531989557266).
# Getting info for (22.075960090301777, -113.97054132011417).
# Getting info for (17.333919249188313, -34.10745095088123).
# Getting info for (16.208326242216003, 164.0862653846799).
# Getting info for (-0.6391234253450762, -106.05648913343191).
# Getting info for (-44.74560229616863, -176.25980246802408).
# Getting info for (-74.04032569496405, 65.00501246147309).
# Getting info for (-38.4861977414051, 137.80129657614953).
# Getting info for (64.81042413081354, -16.254844747942713).
# Getting info for (-69.1186277445585, 65.96241177888547).
# Getting info for (21.70553545498052, -126.45303394549002).
# Getting info for (60.995550100635825, -159.0612124274233).
# Getting info for (-19.831693168824017, 47.069545196696396).
# Getting info for (-53.88789529752708, 13.510541996363258).
# Getting info for (2.026762885892495, 55.06119520478467).
# Getting info for (-88.83725474656845, -47.29157297350477).
# Getting info for (-21.90874643075226, 175.4964411851891).
# Getting info for (-18.99959828210912, 149.6651996248412).
# Getting info for (20.137161718279827, 78.11642193757882).
# Getting info for (55.261984648402034, -85.78454261171943).
# Getting info for (75.9944812951463, -27.285496930172997).
# Getting info for (38.94022095942816, -175.42410906118073).
# Getting info for (30.93521317632873, -60.071186394622146).
# Getting info for (-52.40578923010508, 41.14849598673166).
# Getting info for (-15.633350235486404, -97.05570726759666).
# Getting info for (-63.913689001787546, -76.6867448488525).
# Getting info for (49.37867579509614, -178.66830878384067).
# Getting info for (13.058076201411737, -68.21365938843692).
# Getting info for (-33.68157521695857, 62.48367568108671).
# Getting info for (-40.830747260315945, -23.412303000455438).
# Getting info for (20.483758036663218, -142.45273499876066).
# Getting info for (-28.035983577207908, 76.58601222408339).
# Getting info for (75.47331251604169, 119.57177743150828).
# Getting info for (-60.81642215234737, 70.71411212871988).
# Getting info for (47.29371590379975, -70.48727852468399).
# Getting info for (-60.643866352803144, -26.05006085446533).
# Getting info for (-48.82527028707594, -10.005015250472468).
# Getting info for (78.21796672611677, -60.87123534721118).
# Getting info for (-54.13813072018942, -159.65756200308388).
# Getting info for (-21.200933392946467, 168.4769342027697).
# Getting info for (-16.590230360369333, 137.59247379708603).
# Getting info for (-44.418884176294924, 9.61555945754705).
# Getting info for (6.4145768941332335, -81.11406664006344).
# Getting info for (25.854873876085705, -12.097546724984994).
# Getting info for (-86.22542909850094, -44.64598925671757).
# Getting info for (38.623288923731366, 153.09952740612977).
# Getting info for (-61.59449714433757, -59.14799367310603).
# Getting info for (-2.380162225032251, -51.6406080998257).
# Getting info for (-39.849430742347835, 46.40595406073578).
# Getting info for (-0.8577969394224993, -95.30844324734043).
# Getting info for (29.02298700811268, -0.7918768793792594).
# Getting info for (34.4924636069903, 83.96605431853789).
# Getting info for (-10.550917884721358, 116.0570661558213).
# Getting info for (11.950107849138234, 97.16770695204264).
# Getting info for (-78.7238259592927, 37.93123975374087).
# Getting info for (64.87257689733923, -146.9264174162684).
# Getting info for (-43.77556644475343, 55.30536218310078).
# Getting info for (-72.40384099268334, 83.8759106830446).
# Getting info for (81.60929090645368, 101.67506578437047).
# Getting info for (-40.3418999171644, -167.50615925575806).
# Getting info for (-17.371185946528982, -131.22812696075366).
# Getting info for (88.8322631507308, -56.13529319313757).
# Getting info for (-68.42289537689769, -113.06616571648833).
# Getting info for (-86.80652162989124, -21.946914034752865).
# Getting info for (-50.71289407500918, 41.06744535477944).
# Getting info for (15.077679824419263, -171.4393963333495).
# Getting info for (38.973476381811395, 162.91299803828372).
# Getting info for (-34.4828833525094, -25.95432553944582).
# Getting info for (28.048581603562468, -67.28679895336046).
# Getting info for (63.539571699533354, 114.50898228357715).
# Getting info for (-81.86789289090117, 64.80238189713813).
# Getting info for (-21.13765914836489, -57.31425588989126).
# Getting info for (-2.990001678426566, 29.02827182997848).
# Getting info for (-87.30894284343843, 149.71103203556436).
# Getting info for (5.862601101065152, 175.55879279901558).
# Getting info for (-80.087047663864, 149.40504911670365).
# Getting info for (20.148132782124136, -108.5232890133716).
# Getting info for (-84.03028837745855, -37.480682745098704).
# Getting info for (22.502214799330773, -112.40817311564098).
# Getting info for (-66.78113648032868, 18.95388950079186).
# Getting info for (85.17883324520173, 31.78874027234511).
# Getting info for (36.73659720228372, 2.702679854583664).
# Getting info for (-34.20811217857173, 2.466164810693101).
# Getting info for (2.429165326943206, -118.93563028288368).
# Getting info for (-74.68019280573401, 160.30811310041906).
# Getting info for (-88.0232371883643, -110.62453621586165).
# Getting info for (23.04271711337846, -105.06917694395281).
# Getting info for (28.966793330549706, 149.58764125099253).
# Getting info for (48.910432106111045, 69.20886711876992).
# Getting info for (-26.779801795560857, -161.79091942136688).
# Getting info for (-56.07274959119009, 36.846010311027385).
# Getting info for (-43.31492318325465, -76.4738232179175).
# Getting info for (-47.34126392727672, 1.8017543198736234).
# Getting info for (69.73070872531369, 122.7742008739595).
# Getting info for (65.37276186692804, -138.20271371415893).
# Getting info for (-16.514640756516982, -73.73409178985011).
# Getting info for (-30.03629480453735, -54.096469196454365).
# Getting info for (23.474942737451954, 85.41924210602946).
# Getting info for (59.45079311565382, 175.08332631888948).
# Getting info for (10.031577978264735, -72.60816211986194).
# Getting info for (69.61413383772339, -171.19467355856798).
# Getting info for (-6.457218726832579, 94.32638812823342).
# Getting info for (17.985547138628036, -154.91712909383102).
# Getting info for (-34.58091146794792, 119.10584086759167).
# Getting info for (-70.68794330801892, 111.6626903190508).
# Getting info for (-2.2788640376550973, -65.2777122340299).
# Getting info for (-6.2900545375607635, 21.18799919436549).
# Getting info for (-85.90960594518702, 17.13027953909767).
# Getting info for (44.76178325540394, 38.35074211869562).
# Getting info for (-31.755764475283655, 78.01437612268188).
# Getting info for (35.8231296370774, 9.929399836186207).
# Getting info for (-9.72084794525712, -43.600755704196814).
# Getting info for (-39.702113117378865, 89.40318985255539).
# Getting info for (58.46155005621176, 20.451873176226457).
# Getting info for (28.7611165494463, -4.940838042358166).
# Getting info for (-64.5426987898441, -78.54883902487298).
# Getting info for (84.64998631402179, 67.85550821161195).
# Getting info for (33.90095954739947, 70.3540096092579).
# Getting info for (67.09664856042792, -158.2542423374423).
# Getting info for (-87.67734618625863, -106.47267860693384).
# Getting info for (8.735731722954554, 125.75433434539241).
# Getting info for (-56.27532297685089, 176.52550263192654).
# Getting info for (-76.11156213198018, -90.19724059151136).
# Getting info for (-37.487640361450225, -43.417818926743195).
# Getting info for (29.52951147397704, 54.470568218181114).
# Getting info for (-65.3579477224864, -165.6287210388743).
# Getting info for (52.78486849499137, 76.61973509190932).
# Getting info for (59.398600991654234, -23.690293792597657).
# Getting info for (11.219283134457612, 23.77313075403083).
# Getting info for (87.96094955722592, -55.007921375477366).
# Getting info for (-83.00146486641515, -151.98903788833957).
# Getting info for (26.152310837102263, 140.2701745372641).
# Getting info for (72.28820307969681, 173.22813089964905).
# Getting info for (-6.566818583093266, -97.71408990379734).
# Getting info for (-34.59215105205115, 53.77494352381788).
# Getting info for (-37.02991634791031, -69.27537315401028).
# Getting info for (82.83091791062611, -37.48137974087712).
# Getting info for (82.33661044937787, -98.03887725148523).
# Getting info for (-45.751392698487194, -84.45013980858393).
# Getting info for (78.83920189044193, -175.1855045129614).
# Getting info for (72.70518402124651, 67.57603039861169).
# Getting info for (-56.0877452751282, -156.89309845254027).
# Getting info for (-10.026358359414871, -14.129536334531537).
# Getting info for (-41.47913104350558, -12.24845858942274).
# Getting info for (50.89746583842273, 31.03893318636409).
# Getting info for (46.421203794354994, 123.01268734122442).
# Getting info for (43.323443824040254, 107.28008056583519).
# Getting info for (63.405755291560695, 74.60545488013543).
# Getting info for (8.28808219372928, -55.30204088001).
# Getting info for (-1.897414970365503, 75.54789829262538).
# Getting info for (-22.700370116436886, 140.46376562180308).
# Getting info for (22.375196065730904, 10.514189237442537).
# Getting info for (50.40543521510165, -56.378996248222876).
# Getting info for (-50.85935372508715, -102.80946812869031).
# Getting info for (-73.85819165862853, -170.79993133257574).
# Getting info for (74.29623614596949, -112.74164075491024).
# Getting info for (-79.03442732189575, 144.48816670685432).
# Getting info for (-38.36406533488963, 141.1865681900989).
# Getting info for (48.70631285225778, -107.33549403200324).
# Getting info for (-7.365092800575695, 163.29818349603255).
# Getting info for (-84.63923546283108, 63.061416985441525).
# Getting info for (-79.44675639578601, 109.18709139973004).
# Getting info for (2.9803139296784735, -166.77632832034536).
# Getting info for (-65.282584162971, -48.87381032920945).
# Getting info for (17.33111406846426, -12.8799694048339).
# Getting info for (-66.41438534374896, 36.7824064568521).
# Getting info for (-62.19618990274503, 14.047983072079006).
# Getting info for (-51.03743376127184, 175.35372869755702).
# Getting info for (65.97881019531005, 81.0956313434965).
# Getting info for (-76.1031495771887, -94.29569175855045).
# Getting info for (-58.78624303621792, -29.48198824968307).
# Getting info for (48.15454741240396, -91.86859660483127).
# Getting info for (-59.715105254592956, 58.87626827100814).
# Getting info for (-67.5811855271203, -5.782346073042646).
# Getting info for (6.316246352337913, -29.75862752981587).
# Getting info for (1.4389288946561862, -179.85297140763555).
# Getting info for (20.650241137000265, -107.79304388112772).
# Getting info for (-75.93738621916772, -65.79912701968142).
# Getting info for (21.029131131178985, -161.15759295112719).
# Getting info for (-21.81634852871065, -165.10072730858235).
# Getting info for (-59.741577904387015, -159.77234692099967).
# Getting info for (-41.71169635234748, 80.07578997118281).
# Getting info for (63.462065614924654, 31.161036109131658).
# Getting info for (53.18268781598053, -123.44298271718569).
# Getting info for (-74.44945903302039, -57.48602452041109).
# Getting info for (4.041339137660046, -141.70430608707952).
# Getting info for (-71.54848383632043, 125.7575021138623).
# Getting info for (-30.811532730373045, -44.42074068006772).
# Getting info for (-81.60443027604217, 8.269652495058352).
# Getting info for (17.485360070535208, -23.887925850069422).
# Getting info for (71.79144165166235, 151.41978000658327).
# Getting info for (19.483718829261036, -139.50304791940474).
# Getting info for (73.46441354520346, 154.01948429657114).
# Getting info for (-43.68953425385574, 14.716381996719633).
# Getting info for (5.064713975818563, -13.871491672066298).
# Getting info for (84.68133950541494, -158.34512408738252).
# Getting info for (-54.61728008239275, 15.755211166017972).
# Getting info for (-35.63341952651486, -63.36308309103765).
# Getting info for (45.2848773225474, -11.986732910121106).
# Getting info for (80.20661981055832, -102.32536075470355).
# Getting info for (8.131317447885095, -35.25542634704905).
# Getting info for (-0.21870875155748593, -22.915542726032527).
# Getting info for (72.48261651458895, -73.96740318856197).
# Getting info for (28.702683699846943, -27.178126410927945).
# Getting info for (-56.91867185889612, -159.37238582172532).
# Getting info for (-35.088760883901635, -126.32782865854165).
# Getting info for (55.478770349773754, 128.98440381699606).
# Getting info for (63.37723667205259, 31.765220690954663).
# Getting info for (-8.830120904155379, 139.51087203757874).
# Getting info for (-28.05319001660228, -102.27253274051988).
# Getting info for (11.217228058676952, 116.65364141220965).
# Getting info for (81.28959285176686, 53.06551701057171).
# Getting info for (-85.29258990104694, 156.4145576920634).
# Getting info for (-34.91159604972461, -35.13052907700467).
# Getting info for (86.65058282544271, -97.88135447956162).
# Getting info for (40.65207886307914, 6.405837964588642).
# Getting info for (78.5682220994631, 108.86489134830663).
# Getting info for (-75.52498711986334, -10.733023169989622).
# Getting info for (-54.63663769583627, 85.48771239156588).
# Getting info for (64.79419949852209, -56.900811403263205).
# Getting info for (41.49436163976344, 68.00498670263337).
# Getting info for (1.126685187926256, -144.56108482364152).
# Getting info for (-14.831088908955763, 137.5811779274175).
# Getting info for (-32.05642382156054, -145.21140953615466).
# Getting info for (-21.90472521023122, 25.561059494677693).
# Getting info for (32.90470847877053, -7.296554480979836).
# Getting info for (36.94755666106633, -84.79303287234531).
# Getting info for (-63.18178520556701, 62.61186957684757).
# Getting info for (-53.12130399369262, -71.80758764791821).
# Getting info for (-43.763567093237455, 22.51707365139322).
# Getting info for (0.01678715172107559, 88.4700596288032).
# Getting info for (29.172982982114704, 0.30932183750340414).
# Getting info for (13.066699103833074, -37.46371299675795).
# Getting info for (-35.75129539010735, -105.20207152095962).
# Getting info for (29.981769081629267, 157.12455476702178).
# ...
# Getting info for (73.51594788917703, 120.7747775362804).
# Getting info for (7.06569493678937, -96.78270108849952).
# Getting info for (5.489855127397917, -25.62614626861219).
# Getting info for (-54.03257812657865, 3.646489625088293).
# Getting info for (-66.89235865687493, 43.962628315555946).
# Getting info for (73.37525655048015, 113.82936923715442).
# Getting info for (88.90112807785624, 110.81580227867323).
# Getting info for (73.60509679938832, 173.17227788985315).
# Getting info for (27.98213394029156, 159.42653046633774).
# Getting info for (79.94584401067783, 62.7125451304328).
# Getting info for (-16.150520911926463, -98.45932077753152).
# Getting info for (60.65103480102948, 103.46308691838647).
# Getting info for (-73.56828274243489, 47.06460434973428).
# Getting info for (-36.49497108776625, 138.08483180662853).
# Getting info for (11.707955710618961, -37.31110588568026).
# Getting info for (-20.75903553311943, -45.94557600368705).
# Getting info for (-54.946669860881876, -165.09806474561105).
# Getting info for (-54.97552913361248, 128.2887754009352).
# Getting info for (-33.583180815994524, -60.96086657862003).
# Getting info for (-21.09268292988473, 146.38096756305714).
# Getting info for (-29.055172263389927, 130.4252972042039).
# Getting info for (-42.99352902096348, -42.835262947992504).
# Getting info for (83.42487295222142, -166.99416093150356).
# Getting info for (-13.184481803196519, 5.995412183422587).
# Getting info for (-22.34600949730985, 4.4438563483608675).
# Getting info for (-31.909581740024265, 101.14820372984121).
# Getting info for (51.22981433298162, -159.87943688126884).
# Getting info for (-61.87462167115811, 8.734276806873282).
# Getting info for (35.64161895889218, 121.09735442321454).
# Getting info for (-4.8895157241341565, -110.09421734810934).
# Getting info for (50.562870274621616, 98.10921023480103).
# Getting info for (-9.919923315986026, 1.3174745184359722).
# Getting info for (-69.61729601000367, 33.372164495945896).
# Getting info for (-22.57567078930515, -167.61964280800038).
# Getting info for (40.66603569268298, -63.9305286104662).
# Getting info for (32.71438919981637, 74.99702990378051).
# Getting info for (-6.448153533511203, 153.12278531287836).
# Getting info for (48.10621406673337, 12.474614410215082).
# Getting info for (-57.06064641106693, 160.26741216154613).
# Getting info for (59.716135401511536, 112.01752129028159).
# Getting info for (-9.285683362124644, 62.35819422086476).
# Getting info for (79.33783055923234, -73.3456123336294).
# Getting info for (-55.26893799155391, -89.00279564287344).
# Getting info for (-47.92604044710167, -37.22878858326641).
# Getting info for (57.72689362407678, 167.18448438060852).
# Getting info for (44.25331715275203, -16.510146454829965).
# Getting info for (-81.57123882747284, 31.762471267726966).
# Getting info for (-47.006533504668155, 165.07555711972714).
# Getting info for (-12.52168439632247, 0.6805123757208662).
# Getting info for (-45.47397270083348, 140.60176808638624).
# Getting info for (0.611333327423182, 51.3937470539054).
# Getting info for (31.670380873054754, -10.435618746732672).
# Getting info for (83.93635348147046, 165.49059661625512).
# Getting info for (81.60554245093067, -162.04388553501425).
# Getting info for (3.245260469055083, 99.04867066305661).
# Getting info for (-39.587326718399666, -14.760350633809509).
# Getting info for (-74.29569465163274, 126.26584414555316).
# Getting info for (-14.87807281680226, -22.35499003929806).
# Getting info for (-19.361066341080985, -39.654295375345896).
# Getting info for (-21.943235729288602, 93.87744784346967).
# Getting info for (7.63882593737182, 155.33682814802557).
# Getting info for (-7.1788525198856945, 16.70693611277676).
# Getting info for (-69.7557762289778, 48.54448113255614).
# Getting info for (-46.375701604084306, -146.25447657082427).
# Getting info for (-47.490734100397695, 94.15334287681367).
# Getting info for (11.553514190077806, -92.57083663720516).
# Getting info for (41.128683719630885, 11.628524392419678).
# Getting info for (-32.74089409855016, -89.89665053732233).
# Getting info for (0.46500766619641354, -17.38886575627791).
# Getting info for (81.64427595632768, 39.79977617228889).
# Getting info for (84.77972200715297, -44.22258955608382).
# Getting info for (6.224545334259403, 162.66874601669167).
# Getting info for (-87.38442066566037, 178.53673853336574).
# Getting info for (-47.984358314957326, -104.85132125472036).
# Getting info for (-38.46745933389029, -155.54644596824073).
# Getting info for (85.08747128575644, 116.51109213461177).
# Getting info for (0.3177132956985105, 143.72013223686724).
# Getting info for (9.904087016157021, -54.788731079956946).
# Getting info for (-29.86769826827844, 29.18958260838744).
# Getting info for (78.0813948674562, 64.2236031638858).
# Getting info for (-31.196624303119478, 81.97732895046715).
# Getting info for (39.79281117883994, 24.104035566939302).
# Getting info for (-76.99689424875726, -163.93319124311205).
# Getting info for (-5.127861606604796, -75.86160833068769).
# Getting info for (77.72427145663156, 86.3750513817671).
# Getting info for (51.477551852557696, 81.65405373549163).
# Getting info for (15.127164786308711, -162.40186814147273).
# Getting info for (7.536320387901512, 44.65092873549884).
# Getting info for (39.17860302592888, -47.855701392652435).
# Getting info for (-62.79657217478899, 125.15152858801423).
# Getting info for (11.978006791555813, 90.23832343890103).
# Getting info for (-31.552476942912236, -63.71259205004095).
# Getting info for (-45.60855664081313, -145.22943521837152).
# Getting info for (13.846793240119197, -137.16185612999834).
# Getting info for (53.9924136751346, 105.25800644452062).
# Getting info for (-30.90718447750877, -179.77014081516205).
# Getting info for (74.77663569085391, 0.5292702950812611).
# Getting info for (24.315859122917942, -25.870648983284724).
# Getting info for (-82.22171538830304, -25.536623178627593).
# Getting info for (-17.35460866778405, 38.53496613544945).
# Getting info for (2.6814052017492713, -153.5678020191182).
# Getting info for (-40.14684471355612, 100.0522218977045).
# Getting info for (55.05621491189626, 105.3545350819852).
# Getting info for (-15.993723487904248, 177.45883129396907).
# Getting info for (20.031269042225446, 13.610326605162584).
# Getting info for (48.2495932747629, 67.2011611860533).
# Getting info for (-67.94913749116064, -147.76807592109054).
# Getting info for (9.771744760407941, 157.4690888653514).
# Getting info for (58.29153882834362, 126.68110090619274).
# Getting info for (67.32959563494907, -140.73102690671567).
# Getting info for (-46.24971682859569, 91.50169030511813).
# Getting info for (19.934006073310755, -11.889736762215819).
# Getting info for (38.35161056404186, -104.33351373380535).
# Getting info for (-39.08458325318284, 8.125415612952992).
# Getting info for (65.72542510908599, -51.6023831917787).
# Getting info for (-8.163746668341417, -152.22788074123193).
# Getting info for (-69.96938836879421, 169.74487221695887).
# Getting info for (-52.92176655268478, -175.9853324887901).
# Getting info for (-38.03369526017891, 145.19171563612196).
# Getting info for (21.51478564767571, -24.988204973251044).
# Getting info for (74.49848528909928, -88.3492930623412).
# Getting info for (39.83146342781231, -83.91612803230223).
# Getting info for (-73.07390156427955, 61.93823735523273).
# Getting info for (-60.91476710760676, 150.07305294831133).
# Getting info for (-41.97717797393487, 6.504353085043675).
# Getting info for (-42.48352431454238, -57.70044576940097).
# Getting info for (61.28420418573347, 90.15448806806302).
# Getting info for (35.58142648108267, -155.29034003470562).
# Getting info for (-1.0249360121274549, -164.26095786092014).
# Getting info for (58.39675368655523, -154.05403452142647).
# Getting info for (-16.625141744938944, 25.795750140603644).
# Getting info for (26.65504104188925, -82.7951753313434).
# Getting info for (-16.42496468792322, 174.14057122274494).
# Getting info for (-10.269850375017185, 59.940637457937754).
# Getting info for (-77.54087551451731, -23.84478164343915).
# Getting info for (82.37164492447204, -39.775676156942865).
# Getting info for (-15.087682240459003, 144.5935303225943).
# Getting info for (-0.06775199354139261, -163.32640319336713).
# Getting info for (43.113504139563844, -80.29818526664417).
# Getting info for (-32.56513156245488, -0.8766423455396648).
# Getting info for (16.484448363493783, -64.75772630150355).
# Getting info for (-31.338990746694847, -4.09479166210096).
# Getting info for (7.130605637282898, 98.7409536100651).
# Getting info for (-41.477028735936635, 103.25275414740747).
# Getting info for (38.53179265771459, -137.4036843302712).
# Getting info for (-85.41046041048115, -139.75615641600803).
# Getting info for (-31.42534564935216, 62.03470627198115).
# Getting info for (49.023899201077825, -158.32833131264783).
# Getting info for (-20.19199919851485, -141.54517793038735).
# Getting info for (82.79980012979507, -4.0142006860723995).
# Getting info for (-66.53339429599262, 9.072348875655365).
# Getting info for (-36.68755844365465, 150.96582862128912).
# Getting info for (-58.42293379763226, -51.68082343569054).
# Getting info for (-19.459670596092835, 110.22801067670002).
# Getting info for (40.61383063603358, 50.40022845378374).
# Getting info for (-21.00122622516038, 42.49874238158395).
# Getting info for (-18.500610189868553, 120.60881110089292).
# Getting info for (-43.535895615725636, -84.91054993804633).
# Getting info for (-27.380081400624675, 70.2039399185577).
# Getting info for (46.98778269894319, 173.69452671254749).
# Getting info for (86.31460335708837, 96.95264545496173).
# Getting info for (87.67262876283746, -61.29666050811345).
# Getting info for (62.96756710556389, 43.316701690891136).
# Getting info for (27.53167119165508, 94.91282486153034).
# Getting info for (-49.97779343170513, -36.25311755587336).
# Getting info for (-60.509401238894874, 19.975617456709728).
# Getting info for (-19.33562811266421, 8.745298893360882).
# Getting info for (-56.490119696936034, -103.09052750669946).
# Getting info for (68.32361934931097, 152.93508522541947).
# Getting info for (-31.217295377242415, 101.53604222734748).
# Getting info for (53.8480099875801, 78.18956738169425).
# Getting info for (-5.276460635660428, 4.551396029391469).
# Getting info for (25.51401966164339, 3.3552490352929567).
# Getting info for (35.06661736722363, -19.973872761071874).
# Getting info for (-0.08318301295390995, 163.36575236476835).
# Getting info for (77.96552323151474, 9.836438529768401).
# Getting info for (-63.25820077873948, -139.1220365543379).
# Getting info for (-3.13517885608573, 53.2654926771977).
# Getting info for (-50.18838723631553, -54.156688955814985).
# Getting info for (56.26756843031703, -71.89056335415835).
# Getting info for (24.179077029493627, -15.659370683190815).
# Getting info for (5.095645135999931, -91.23977984978599).
# Getting info for (-8.95325344720682, 52.02353827308394).
# Getting info for (-11.759756668049533, 41.47828960187974).
# Getting info for (33.29520287044291, 94.45760386645532).
# Getting info for (65.79545718113124, -177.81904744151802).
# Getting info for (-46.60536218781606, 104.61371126489229).
# Getting info for (-13.959484064117646, -158.00445391075576).
# Getting info for (38.81597634661344, 12.721166723369237).
# Getting info for (-6.960692304067408, 99.25766771918586).
# Getting info for (14.708993543065816, 148.72214554962778).
# Getting info for (0.45226394528357616, -78.03796010190783).
# Getting info for (31.50424958699317, 116.45228314948963).
# Getting info for (-6.264008979278287, -12.52185614246261).
# Getting info for (9.144063555559384, -153.627405883399).
# Getting info for (-26.991566413336137, 135.50250695710548).
# Getting info for (-89.50382873996271, -80.01592256264892).
# Getting info for (-46.589715473289935, 17.108360324641865).
# Getting info for (88.29704765900479, 58.88751550698956).
# Getting info for (75.67839415962237, -22.30935245687192).
# Getting info for (-31.788743514827424, -123.65394278901886).
# Getting info for (-8.994603621713424, 35.30469643357904).
# Getting info for (67.33153151900481, -179.47709166140396).
# Getting info for (5.045507223912466, 177.97861899162558).
# Getting info for (4.727593812634339, -58.16964587458207).
# Getting info for (28.41427106189397, -138.3774612158382).
# Getting info for (-1.1558314351479453, 102.27185631261426).
# Getting info for (55.30431123476501, 67.79823053800524).
# Getting info for (69.20797489608015, 43.23163919923806).
# Getting info for (46.281315072488724, -171.86559054463297).
# Getting info for (25.180038545506903, -48.38538090895625).
# Getting info for (-51.601032424450544, 118.63516233736135).
# Getting info for (2.048747167422917, 142.96511337324796).
# Getting info for (-21.791616116567198, 102.99043504504527).
# Getting info for (73.1679351668493, -159.6805049975393).
# Getting info for (59.56012887754508, -129.8349683699178).
# Getting info for (25.854857659866198, 11.774992785012188).
# Getting info for (-11.054503900316135, 103.0862409938618).
# Getting info for (25.22419118737038, -48.492817609839676).
# Getting info for (24.212305808603062, -100.38663330779718).
# Getting info for (3.4033800490087174, 63.65235865693873).
# Getting info for (-44.34853275566397, -49.56848671539137).
# Getting info for (69.27644258424544, -40.175658420984405).
# Getting info for (27.14031473979982, -148.82882285397858).
# Getting info for (2.2705853397050078, 149.76060834631414).
# Getting info for (63.230472205932074, -168.62906469133546).
# Getting info for (14.466111841476504, -106.45428416900496).
# Getting info for (-66.37260819747085, -94.34469373330168).
# Getting info for (-10.350328144674108, 87.55186708511485).
# Getting info for (18.087775283437054, 72.11007410048035).
# Getting info for (49.8404389088785, 134.51825516826625).
# Getting info for (85.19339492476189, -155.69269837568885).
# Getting info for (-60.04995950132344, -13.03585742052752).
# Getting info for (-25.804943196470205, 163.01934964496758).
# Getting info for (68.44712089986535, -33.86838862690371).
# Getting info for (-39.99243157833799, 1.5376255195544388).
# Getting info for (-10.130940766518378, -132.19822035231118).
# Getting info for (-11.889401437654854, 51.75960689276687).
# Getting info for (-53.33246065522054, -63.38082531548386).
# Getting info for (5.55721251304557, -23.025749959205513).
# Getting info for (-1.6980370268982625, -101.99199324824919).
# Getting info for (20.89046836391134, 92.04173567702588).
# Getting info for (26.589151422544177, -112.74899899991354).
# Getting info for (61.24948291819254, -115.99101092197989).
# Getting info for (-10.683405297689035, 82.24746963811998).
# Getting info for (77.72453048584632, 160.61682640906707).
# Getting info for (16.878242292144833, 27.180003234967103).
# Getting info for (69.11067066781487, -82.06307833527394).
# Getting info for (-19.452517666480617, -103.44977122719445).
# Getting info for (-49.97700852694214, -147.93738974058343).
# Getting info for (-14.057263442197566, 58.43606638500427).
# Getting info for (59.77477993974722, -96.52960105727112).
# Getting info for (45.57935938943234, -156.657149960872).
# Getting info for (69.60877480556871, -76.28709127469281).
# Getting info for (82.62194435147373, -107.21080885972987).
# Getting info for (-13.328109812624504, 99.27738027200894).
# Getting info for (21.427162185847934, -163.5470458080462).
# Getting info for (-41.47279458741707, 143.85949485874028).
# Getting info for (-51.83460009711179, 149.00668032859198).
# Getting info for (-45.75233088942149, 108.95440919077879).
# Getting info for (14.22695852095356, 27.040469061390894).
# Getting info for (-64.0972857220042, -110.37053377779205).
# Getting info for (-48.47962039846865, 59.451457767772865).
# Getting info for (-59.87403748512622, -123.93262279016064).
# Getting info for (-81.73110740773883, -147.63358130899798).
# Getting info for (8.423085925308754, -70.9890334051514).
# Getting info for (-17.874925181383418, -162.97146833164783).
# Getting info for (-20.951025109742503, 137.59193155725006).
# Getting info for (2.203597765725604, -155.91357592452803).
# Getting info for (34.793663073758424, 162.5430443246255).
# Getting info for (9.435744025022359, 49.54431090684281).
# Getting info for (16.1526210577601, -69.5668636769306).
# 614

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q={city}"

record = 0
set_ct = 1
temperatures = []
humidity = []
wind_speed = []
country_list = []
cloudy = []
dates = []
latitude = []
longitude = []
city_df = []

# print(cities)
print("Beginning Data Retrieval")
print("-----------------------------")

for city in cities:
    record += 1
    try:
        query_url = f"{url}appid={api_key}&units={units}&q={city}"
        weather_response = requests.get(query_url)
#         print(weather_response.status_code)
        weather_json = weather_response.json()
#        pprint(weather_json)
        print(f"Processing Record {record} of Set {set_ct} | {city}")
        time.sleep(1)
        
        city_df.append(weather_json["name"])
        temperatures.append(weather_json["main"]["temp_max"])
        humidity.append(weather_json["main"]["humidity"])
        wind_speed.append(weather_json["wind"]["speed"])
        country_list.append(weather_json["sys"]["country"])
        cloudy.append(weather_json["clouds"]["all"])  
        dates.append(weather_json["dt"])
        latitude.append(weather_json["coord"]["lat"])
        longitude.append(weather_json["coord"]["lon"])

    except KeyError:
        print("City not found. Skipping...")
        
    if record == 50:
        record = 0
        set_ct += 1
        

print("-----------------------------")
print("Data Retrieval Complete")    
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | souillac
# Processing Record 3 of Set 1 | te anau
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | biak
# Processing Record 7 of Set 1 | maniitsoq
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | hithadhoo
# Processing Record 10 of Set 1 | lagoa
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | cherskiy
# Processing Record 13 of Set 1 | rivne
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | dobryanka
# Processing Record 16 of Set 1 | coihaique
# Processing Record 17 of Set 1 | saint-philippe
# Processing Record 18 of Set 1 | vardo
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | praia da vitoria
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | guerrero negro
# Processing Record 23 of Set 1 | cockburn town
# Processing Record 24 of Set 1 | pevek
# Processing Record 25 of Set 1 | key largo
# Processing Record 26 of Set 1 | yumen
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | khatanga
# Processing Record 29 of Set 1 | tombouctou
# Processing Record 30 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | tuktoyaktuk
# Processing Record 34 of Set 1 | bandarbeyla
# Processing Record 35 of Set 1 | ugoofaaru
# Processing Record 36 of Set 1 | balkanabat
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | clyde river
# Processing Record 39 of Set 1 | vytegra
# Processing Record 40 of Set 1 | nanortalik
# Processing Record 41 of Set 1 | arraial do cabo
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | olavarria
# Processing Record 47 of Set 1 | bethel
# Processing Record 48 of Set 1 | butaritari
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | atuona
# Processing Record 2 of Set 2 | new norfolk
# Processing Record 3 of Set 2 | heyang
# Processing Record 4 of Set 2 | georgetown
# Processing Record 5 of Set 2 | manicore
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | huarmey
# Processing Record 8 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 2 | tanabe
# Processing Record 10 of Set 2 | nyaunglebin
# Processing Record 11 of Set 2 | avarua
# Processing Record 12 of Set 2 | chokurdakh
# Processing Record 13 of Set 2 | rawson
# Processing Record 14 of Set 2 | pousat
# City not found. Skipping...
# Processing Record 15 of Set 2 | fort nelson
# Processing Record 16 of Set 2 | astana
# Processing Record 17 of Set 2 | goderich
# Processing Record 18 of Set 2 | port lincoln
# Processing Record 19 of Set 2 | geraldton
# Processing Record 20 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 2 | san-pedro
# Processing Record 22 of Set 2 | sur
# Processing Record 23 of Set 2 | sitka
# Processing Record 24 of Set 2 | bambous virieux
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 2 | borger
# Processing Record 28 of Set 2 | basco
# Processing Record 29 of Set 2 | puerto gaitan
# City not found. Skipping...
# Processing Record 30 of Set 2 | axim
# Processing Record 31 of Set 2 | maningrida
# Processing Record 32 of Set 2 | jamestown
# Processing Record 33 of Set 2 | touros
# Processing Record 34 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 2 | kindu
# Processing Record 36 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 2 | high level
# Processing Record 38 of Set 2 | east london
# Processing Record 39 of Set 2 | lebu
# Processing Record 40 of Set 2 | fairbanks
# Processing Record 41 of Set 2 | aklavik
# Processing Record 42 of Set 2 | saint george
# Processing Record 43 of Set 2 | burica
# City not found. Skipping...
# Processing Record 44 of Set 2 | luanda
# Processing Record 45 of Set 2 | abdulino
# Processing Record 46 of Set 2 | faya
# Processing Record 47 of Set 2 | lavrentiya
# Processing Record 48 of Set 2 | bengkulu
# City not found. Skipping...
# Processing Record 49 of Set 2 | college
# Processing Record 50 of Set 2 | tiksi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len
# Out:
# 595

# %%
weather_df = pd.DataFrame({
    "City": city_df,
    "Cloudiness": cloudy,
    "Country": country_list,
    "Date": dates,
    "Humidity": humidity,
    "Lat": latitude,
    "Lng": longitude,
    "Max Temp": temperatures,
    "Wind Speed": wind_speed  
    })

weather_df.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    Ushuaia          40      AR  1566672631        66 -54.81  -68.31
# 1   Souillac           0      FR  1566672632        26  45.60   -0.60
# 2    Te Anau          82      NZ  1566672445        81 -45.41  167.72
# 3    Mataura          77      NZ  1566672342        87 -46.19  168.86
# 4  Cape Town          20      ZA  1566672393        93 -33.93   18.42
#
#    Max Temp  Wind Speed
# 0     48.20       14.99
# 1     91.40        6.93
# 2     44.95        9.82
# 3     42.01        1.01
# 4     62.01       17.22

# %%
weather_df.count()
# Out:
# City          87
# Cloudiness    87
# Country       87
# Date          87
# Humidity      87
# Lat           87
# Lng           87
# Max Temp      87
# Wind Speed    87
# dtype: int64

# %%
# Export file as a CSV
weather_df.to_csv("Output/WeatherDataFrame.csv", index=False, header=True)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df.count()
# Out:
# City          18
# Cloudiness    18
# Country       18
# Date          18
# Humidity      18
# Lat           18
# Lng           18
# Max Temp      18
# Wind Speed    18
# dtype: int64

# %%
# Out:
# City          547
# Cloudiness    547
# Country       547
# Date          547
# Humidity      547
# Lat           547
# Lng           547
# Max Temp      547
# Wind Speed    547
# dtype: int64

# %%
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     lompoc           1      US  1534984500        44  34.64 -120.46
# 1   klaksvik          92      FO  1534983600       100  62.23   -6.59
# 2  bisignano           0      IT  1534981800        88  39.50   16.27
# 3       hilo          90      US  1534984860        90  19.71 -155.08
# 4    rikitea           8      PF  1534986579       100 -23.12 -134.97
#
#    Max Temp  Wind Speed
# 0     77.00       11.41
# 1     50.00       13.87
# 2     66.20        5.82
# 3     77.00        8.05
# 4     69.58       19.71

# %%
plt.title("City Latitude vs Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.scatter(latitude, temperatures, marker="o", facecolors="blue", edgecolors="black",
            s=50, alpha=0.5)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.savefig("Output/LatVsMaxTemp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.title("City Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.scatter(latitude, humidity, marker="o", facecolors="blue", edgecolors="black",
            s=50, alpha=0.5)

# %%
plt.savefig("Output/LatVsHum.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.title("City Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.scatter(latitude, cloudy, marker="o", facecolors="blue", edgecolors="black",
            s=50, alpha=0.5)

# %%
plt.savefig("Output/LatVsCloud.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.title("City Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.scatter(latitude, wind_speed, marker="o", facecolors="blue", edgecolors="black",
            s=50, alpha=0.5)

# %%
plt.savefig("Output/LatVsWind.png")
